# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = "/content/drive/MyDrive/ML/stroke.csv"

# %%
df = pd.read_csv(file)
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.drop("id",axis=1,inplace=True)
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             5110 non-null   object
#  1   age                5110 non-null   float64
#  2   hypertension       5110 non-null   int64
#  3   heart_disease      5110 non-null   int64
#  4   ever_married       5110 non-null   object
#  5   work_type          5110 non-null   object
#  6   Residence_type     5110 non-null   object
#  7   avg_glucose_level  5110 non-null   float64
#  8   bmi                4909 non-null   float64
#  9   smoking_status     5110 non-null   object
#  10  stroke             5110 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 439.3+ KB

# %%
df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  5110.000000   5110.000000    5110.000000        5110.000000
# mean     43.226614      0.097456       0.054012         106.147677
# std      22.612647      0.296607       0.226063          45.283560
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.245000
# 50%      45.000000      0.000000       0.000000          91.885000
# 75%      61.000000      0.000000       0.000000         114.090000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4909.000000  5110.000000
# mean     28.893237     0.048728
# std       7.854067     0.215320
# min      10.300000     0.000000
# 25%      23.500000     0.000000
# 50%      28.100000     0.000000
# 75%      33.100000     0.000000
# max      97.600000     1.000000

# %%
df.corr()
# Out:
# <ipython-input-22-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                         age  hypertension  heart_disease  avg_glucose_level  \
# age                1.000000      0.276398       0.263796           0.238171
# hypertension       0.276398      1.000000       0.108306           0.174474
# heart_disease      0.263796      0.108306       1.000000           0.161857
# avg_glucose_level  0.238171      0.174474       0.161857           1.000000
# bmi                0.333398      0.167811       0.041357           0.175502
# stroke             0.245257      0.127904       0.134914           0.131945
#
#                         bmi    stroke
# age                0.333398  0.245257
# hypertension       0.167811  0.127904
# heart_disease      0.041357  0.134914
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-23-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# 5       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 5104  Female  13.0             0              0           No       children
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %% [markdown]
# # EDA

# %%
sns.FacetGrid(df,hue="stroke").map(plt.scatter,"age","heart_disease").add_legend()

# %%
plt.hist(df.age,bins=25);

# %%
plt.hist(df.bmi,bins=25)
# Out:
# (array([ 13., 188., 462., 740., 972., 914., 674., 403., 241., 152.,  55.,
#          36.,  28.,  17.,   6.,   3.,   1.,   1.,   0.,   1.,   0.,   0.,
#           0.,   1.,   1.]),
#  array([0.  , 0.04, 0.08, 0.12, 0.16, 0.2 , 0.24, 0.28, 0.32, 0.36, 0.4 ,
#         0.44, 0.48, 0.52, 0.56, 0.6 , 0.64, 0.68, 0.72, 0.76, 0.8 , 0.84,
#         0.88, 0.92, 0.96, 1.  ]),
#  <BarContainer object of 25 artists>)

# %%
sns.pairplot(df)

# %% [markdown]
# ## preprocessing

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# 5       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 5104  Female  13.0             0              0           No       children
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %% [markdown]
# #### LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.gender = le.fit_transform(df.gender)

# %%
print(df.ever_married.unique())
print(df.work_type.unique())
print(df.Residence_type.unique())
print(df.smoking_status.unique())
# Out:
# [0]
# ['Private' 'Self-employed' 'Govt_job' 'children' 'Never_worked']
# ['Urban' 'Rural']
# ['formerly smoked' 'never smoked' 'smokes' 'Unknown']

# %%
df.ever_married = le.fit_transform(df.ever_married)
df.work_type = le.fit_transform(df.work_type)
df.Residence_type = le.fit_transform(df.Residence_type)
df.smoking_status = le.fit_transform(df.smoking_status)

# %%
df
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             0          2
# 2          1  80.0             0              1             0          2
# 3          0  49.0             0              0             0          2
# 4          0  79.0             1              0             0          3
# 5          1  81.0             0              0             0          2
# ...      ...   ...           ...            ...           ...        ...
# 5104       0  13.0             0              0             0          4
# 5106       0  81.0             0              0             0          3
# 5107       0  35.0             0              0             0          3
# 5108       1  51.0             0              0             0          2
# 5109       0  44.0             0              0             0          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# ...

# %% [markdown]
# ### MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
df.avg_glucose_level = scaler.fit_transform(df[["avg_glucose_level"]])      # -1 to 1

# %%
df
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             0          2
# 2          1  80.0             0              1             0          2
# 3          0  49.0             0              0             0          2
# 4          0  79.0             1              0             0          3
# 5          1  81.0             0              0             0          2
# ...      ...   ...           ...            ...           ...        ...
# 5104       0  13.0             0              0             0          4
# 5106       0  81.0             0              0             0          3
# 5107       0  35.0             0              0             0          3
# 5108       1  51.0             0              0             0          2
# 5109       0  44.0             0              0             0          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# ...

# %%
df.bmi = scaler.fit_transform(df[["bmi"]])

# %%
df
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             0          2
# 2          1  80.0             0              1             0          2
# 3          0  49.0             0              0             0          2
# 4          0  79.0             1              0             0          3
# 5          1  81.0             0              0             0          2
# ...      ...   ...           ...            ...           ...        ...
# 5104       0  13.0             0              0             0          4
# 5106       0  81.0             0              0             0          3
# 5107       0  35.0             0              0             0          3
# 5108       1  51.0             0              0             0          2
# 5109       0  44.0             0              0             0          0
#
#       Residence_type  avg_glucose_level       bmi  smoking_status  stroke
# ...

# %%
df.age = scaler.fit_transform(df[["age"]])

# %%
df.head()
# Out:
#    gender       age  hypertension  heart_disease  ever_married  work_type  \
# 0       1  0.816895             0              1             0          2
# 2       1  0.975586             0              1             0          2
# 3       0  0.597168             0              0             0          2
# 4       0  0.963379             1              0             0          3
# 5       1  0.987793             0              0             0          2
#
#    Residence_type  avg_glucose_level       bmi  smoking_status  stroke
# 0               1           0.801265  0.301260               1       1
# 2               0           0.234512  0.254296               2       1
# 3               1           0.536008  0.276060               3       1
# 4               0           0.549349  0.156930               2       1
# 5               1           0.605161  0.214204               1       1

# %% [markdown]
# ## model selection

# %%
from sklearn.linear_model import LogisticRegressionCV as lrcv

# %%
classifier = lrcv()

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop("stroke",axis = 1)
y = df['stroke']

# %%
X,y
# Out:
# (      gender       age  hypertension  heart_disease  ever_married  work_type  \
#  0          1  0.816895             0              1             0          2
#  2          1  0.975586             0              1             0          2
#  3          0  0.597168             0              0             0          2
#  4          0  0.963379             1              0             0          3
#  5          1  0.987793             0              0             0          2
#  ...      ...       ...           ...            ...           ...        ...
#  5104       0  0.157715             0              0             0          4
#  5106       0  0.987793             0              0             0          3
#  5107       0  0.426270             0              0             0          3
#  5108       1  0.621582             0              0             0          2
#  5109       0  0.536133             0              0             0          0
#
# ...

# %%
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
y_test.value_counts()
# Out:
# 0    1401
# 1      72
# Name: stroke, dtype: int64

# %%
clf = classifier.fit(X_train,y_train)

# %%
y_pred = clf.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.9511201629327902

# %%
# gender,age,hypertension,heart_disease,ever_married,work_type,Residence_type,avg_glucose_level,bmi,smoking_status
#input_data = 1,80.0,0,1,0,2,0,0.234512,32.5,2                      # 1
#input_data = 0,0.987793,0,0,0,3,1,0.323516,0.340206,2              # 0
#input_data = 0,0.963379,0,0,0,3,1,0.801311,0.186712,2              # 1
#input_data = 0,0.536133,0,0,0,0,1,0.139230,0.182131, 0             # 0
#input_data = 0,0.951172,0,0,0,2,1,0.015927,0.159221,0              # 1
#input_data = 0,0.426270,0,0,0,3,0,0.128658,0.232532,2              # 0
#input_data = 1,0.780273,0,1,0,2,1,0.630090,0.311569,3	            # 1

# %%
input_data_as_np_array = np.asarray(input_data)
input_data_reshaped = input_data_as_np_array.reshape(1,-1)
print(input_data_reshaped.shape)
# Out:
# (1, 10)

# %%
prediction = clf.predict(input_data_reshaped)
print(prediction[0])
if (prediction[0] == 1):
  out = "This person suffering from stroke"
else:
  out = "This person did not suffer from a stroke"
print(out)
print(f"{round(accuracy_score(y_pred,y_test)*100,2)}% Accuracy in Logistic Regression cross-validation classifier.")
# Out:
# 0
# This person did not suffer from a stroke
# 95.11% Accuracy in Logistic Regression cross-validation classifier.

# %% [markdown]
# ## Save to pickled file using joblib

# %%
from joblib import Parallel, delayed
import joblib

# %%
# Save the model as a pickle in a file
joblib.dump(clf, 'stroke_prediction.pkl')

# Load the model from the file
clf_from_joblib = joblib.load('stroke_prediction.pkl')

# Use the loaded model to make predictions
clf_from_joblib.predict(input_data_reshaped)
# Out:
# array([0])
